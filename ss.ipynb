# %%
import joblib

# %%
data=([
    {
        "name": "John Doe",
        "teacher_id": "T12345",
        "school": "ABC High School",
        "date_of_birth": "1980-05-15",
        "password": "12345",
        "email": "john.doe@example.com",
        "subjects_taught": [
            "Mathematics",
            "Physics",
            "Computer Science"
        ],
        "classes": [
            "Class 10 Physics",
            "Class 12 Physics",
            "Class 11 Science"
        ],
        "teaching_performance": {
            "student_feedback": "Positive",
            "peer_reviews": "Excellent",
            "performance_ratings": "4.8/5"
        },
        "qualifications": [
            "B.Sc. in Mathematics",
            "M.Sc. in Physics",
            "Ph.D. in Computer Science"
        ],
        "years_of_experience": 15,
        "weekly_class_performance": {
            "Class 10 Physics": [90, 85, 88, 92, 87, 90, 93],  # Performance scores for the past 7 weeks
            "Class 12 Physics": [80, 75, 78, 82, 77, 80, 83],
            "Class 11 Science": [70, 65, 68, 72, 67, 70, 73]}
    },
    {
        "name": "Jane Smith",
        "teacher_id": "T67890",
        "school": "ABC High School",
        "date_of_birth": "1975-11-25",
        "email": "jane.smith@example.com",
        "subjects_taught": [
            "English",
            "History",
            "Geography"
        ],
        "classes": [
            "Class 9 English",
            "Class 10 History",
            "Class 11 Geography"
        ],
        "teaching_performance": {
            "student_feedback": "Excellent",
            "peer_reviews": "Very Good",
            "performance_ratings": "4.7/5"
        },
        "qualifications": [
            "B.A. in English Literature",
            "M.A. in History",
            "Postgraduate Diploma in Geography"
        ],
        "years_of_experience": 20,
        "weekly_class_performance": {
            "Class 10 Physics": [90, 85, 88, 92, 87, 90, 93],  # Performance scores for the past 7 weeks
            "Class 12 Physics": [80, 75, 78, 82, 77, 80, 83],
            "Class 11 Science": [70, 65, 68, 72, 67, 70, 73]}
    }
]

, [
    {
        "name": "Alice Johnson",
        "age": 20,
        "cgpa": 3.6,
        "course_pursuing": "Computer Science",
        "assigned_test_score": 85.5,
        "ai_test_score": 88.2,
        "interests": ["Programming", "AI"],
        "areas_to_improve": "Mathematics",
        "courses_taken": ["Intro to CS", "Data Structures"],
        "password": '12345',
        "school": "State University",
        "dob": "2004-05-15",
        "email": "alice.johnson@stateu.edu"
    },
    {
        "name": "Bob Smith",
        "age": 22,
        "cgpa": 3.8,
        "course_pursuing": "Mechanical Engineering",
        "assigned_test_score": 90,
        "ai_test_score": 91.5,
        "interests": ["Robotics", "Mechanics"],
        "areas_to_improve": "Thermodynamics",
        "courses_taken": ["Intro to ME", "Mechanics of Materials"],
        "password": '12345',
        "school": "State University",
        "dob": "2002-08-22",
        "email": "bob.smith@stateu.edu"
    },
    {
        "name": "Cathy Brown",
        "age": 21,
        "cgpa": 3.7,
        "course_pursuing": "Psychology",
        "assigned_test_score": 78,
        "ai_test_score": 85,
        "interests": ["Human Behavior", "Cognitive Science"],
        "areas_to_improve": "Statistics",
        "courses_taken": ["Intro to Psychology", "Cognitive Neuroscience"],
        "password": '12345',
        "school": "State University",
        "dob": "2003-11-12",
        "email": "cathy.brown@stateu.edu"
    },
    {
        "name": "David Green",
        "age": 19,
        "cgpa": 3.9,
        "course_pursuing": "Electrical Engineering",
        "assigned_test_score": 82.5,
        "ai_test_score": 85,
        "interests": ["Electronics", "Circuit Design"],
        "areas_to_improve": "Control Systems",
        "courses_taken": ["Circuits", "Signals and Systems"],
        "password": '12345',
        "school": "State University",
        "dob": "2004-02-25",
        "email": "david.green@stateu.edu"
    },
    {
        "name": "Eva White",
        "age": 23,
        "cgpa": 3.7,
        "course_pursuing": "Biology",
        "assigned_test_score": 92,
        "ai_test_score": 94,
        "interests": ["Genetics", "Microbiology"],
        "areas_to_improve": "Biochemistry",
        "courses_taken": ["Intro to Biology", "Genetics"],
        "password": '12345',
        "school": "State University",
        "dob": "2000-09-09",
        "email": "eva.white@stateu.edu"
    },
    {
        "name": "Frank Black",
        "age": 21,
        "cgpa": 3.7,
        "course_pursuing": "Business Administration",
        "assigned_test_score": 87,
        "ai_test_score": 87.5,
        "interests": ["Marketing", "Finance"],
        "areas_to_improve": "Accounting",
        "courses_taken": ["Principles of Management", "Marketing"],
        "password": '12345',
        "school": "State University",
        "dob": "2003-04-20",
        "email": "frank.black@stateu.edu"
    },
    {
        "name": "Grace Lee",
        "age": 20,
        "cgpa": 3.4,
        "course_pursuing": "Art History",
        "assigned_test_score": 88,
        "ai_test_score": 88,
        "interests": ["Renaissance Art", "Modern Art"],
        "areas_to_improve": "Art Theory",
        "courses_taken": ["Intro to Art History", "Modern Art"],
        "password": '12345',
        "school": "State University",
        "dob": "2004-07-03",
        "email": "grace.lee@stateu.edu"
    },
    {
        "name": "Henry Adams",
        "age": 22,
        "cgpa": 3.3,
        "course_pursuing": "Mathematics",
        "assigned_test_score": 85,
        "ai_test_score": 86.5,
        "interests": ["Algebra", "Calculus"],
        "areas_to_improve": "Topology",
        "courses_taken": ["Calculus I", "Linear Algebra"],
        "password": '12345',
        "school": "State University",
        "dob": "2002-12-30",
        "email": "henry.adams@stateu.edu"
    },
    {
        "name": "Ivy Clarke",
        "age": 20,
        "cgpa": 3.3,
        "course_pursuing": "Environmental Science",
        "assigned_test_score": 79.5,
        "ai_test_score": 81,
        "interests": ["Ecology", "Conservation"],
        "areas_to_improve": "Chemistry",
        "courses_taken": ["Intro to Environmental Science", "Ecology"],
        "password": '12345',
        "school": "State University",
        "dob": "2004-06-10",
        "email": "ivy.clarke@stateu.edu"
    },
    {
        "name": "Jack Davis",
        "age": 21,
        "cgpa": 3.5,
        "course_pursuing": "Chemistry",
        "assigned_test_score": 83,
        "ai_test_score": 84.5,
        "interests": ["Organic Chemistry", "Analytical Chemistry"],
        "areas_to_improve": "Physical Chemistry",
        "courses_taken": ["Intro to Chemistry", "Organic Chemistry"],
        "password": '12345',
        "school": "State University",
        "dob": "2003-03-17",
        "email": "jack.davis@stateu.edu"
    }
]
)

# %%
joblib.dump(data,r'C:\Users\tiruv\Downloads\Falcon\Falcon\database.pkl')
# Out:
# ['C:\\Users\\tiruv\\Downloads\\Falcon\\Falcon\\database.pkl']

# %%
a=joblib.load(r'C:\Users\tiruv\Downloads\Falcon\Falcon\database.pkl')

# %%
student_data=a[0]
student_data
# Out:
# [{'name': 'John Doe',
#   'teacher_id': 'T12345',
#   'school': 'ABC High School',
#   'date_of_birth': '1980-05-15',
#   'password': '12345',
#   'email': 'john.doe@example.com',
#   'subjects_taught': ['Mathematics', 'Physics', 'Computer Science'],
#   'classes': ['Class 10 Physics', 'Class 12 Physics', 'Class 11 Science'],
#   'teaching_performance': {'student_feedback': 'Positive',
#    'peer_reviews': 'Excellent',
#    'performance_ratings': '4.8/5'},
#   'qualifications': ['B.Sc. in Mathematics',
#    'M.Sc. in Physics',
#    'Ph.D. in Computer Science'],
#   'years_of_experience': 15,
#   'weekly_class_performance': {'Class 10 Physics': [90,
#     85,
#     88,
#     92,
#     87,
#     90,
#     93],
#    'Class 12 Physics': [80, 75, 78, 82, 77, 80, 83],
#    'Class 11 Science': [70, 65, 68, 72, 67, 70, 73]}},
#  {'name': 'Jane Smith',
#   'teacher_id': 'T67890',
#   'school': 'ABC High School',
#   'date_of_birth': '1975-11-25',
#   'email': 'jane.smith@example.com',
# ...
